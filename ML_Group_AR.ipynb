# %% [markdown]
# # Machine Learning Project — Group AR

# %% [markdown]
# ## Table of Contents
#
# 1. [Business Understanding](#1-business-understanding)
# 2. [Data Understanding](#2-data-understanding)
# 3. [Data Preparation](#3-data-preparation)
# 4. [Modelling](#4-modelling)
# 5. [Model Evaluation & Comparison](#5-model-evaluation--comparison)
# 6. [Business Interpretation & Recommendations](#6-business-interpretation--recommendations)
# 7. [References](#references)

# %% [markdown]
# ## 1. Business Understanding
#
# This project uses the **IBM HR Analytics Employee Attrition** dataset to predict which employees are likely to leave the company (**attrition**). Understanding and anticipating attrition is a high-value business problem: replacing an employee can cost 50–200% of their annual salary, and voluntary turnover disrupts team continuity and knowledge retention.
#
# **Objective:** Build a supervised classification model that identifies employees at high risk of leaving, based on demographic, job-related, and satisfaction features.
#
# **Success criteria:**
# - **Primary metric:** ROC-AUC ≥ 0.80 — captures the model's ability to rank at-risk employees above low-risk ones.
# - **Secondary metric:** F1-score (Attrition class) — balances precision and recall, important because false negatives (missed leavers) carry a high business cost.
# - The final model should be interpretable enough to inform HR interventions.

# %% [markdown]
# The attrition prediction problem is a **binary supervised classification** task: given a set of features describing an employee, predict whether that employee will leave (1) or stay (0). We evaluate four model families — Logistic Regression, Random Forest, Gradient Boosting, and a Neural Network — chosen to span the interpretability–complexity spectrum. This allows us to assess whether the performance gains from more complex models justify the loss of interpretability, which is critical for actionable HR recommendations.

# %% [markdown]
# ---
#
# ## 2. Data Understanding
#
# This section loads the dataset, audits its structure and quality, and explores the distributions and relationships of individual variables. The goal is to understand the data before any transformations are applied, identify potential issues (missing values, outliers, imbalance), and generate hypotheses about which features may be predictive of attrition.

# %% [markdown]
# ### 2.1 Data Loading
#
# The dataset is loaded from a pinned GitHub commit permalink to ensure reproducibility across environments. All library imports for the project are consolidated in the code cell below.

# %%
# ─── Standard library ─────────────────────────────────────────────────────────
import math
import itertools
import warnings
from pathlib import Path

# ─── Data manipulation ────────────────────────────────────────────────────────
import numpy as np
import pandas as pd
import scipy.stats as stats

# ─── Visualisation ────────────────────────────────────────────────────────────
import matplotlib.pyplot as plt
import seaborn as sns

# ─── Machine learning ─────────────────────────────────────────────────────────
from sklearn.model_selection import (
    train_test_split, cross_val_score,
    GridSearchCV, RandomizedSearchCV,
    StratifiedKFold, cross_val_predict,
)
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.base import clone
from sklearn.metrics import (
    classification_report, confusion_matrix,
    roc_auc_score, roc_curve, average_precision_score,
    f1_score, RocCurveDisplay, ConfusionMatrixDisplay,
)
from sklearn.inspection import permutation_importance
from sklearn.utils.class_weight import compute_class_weight, compute_sample_weight

# ─── Deep learning ────────────────────────────────────────────────────────────
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks, regularizers

warnings.filterwarnings("ignore")

# %% [markdown]
# We load the dataset from a GitHub commit permalink so the analysis is reproducible. We confirm 1470 observations and 35 variables, then show the first rows.

# %%
# Load dataset from GitHub commit permalink (online, reproducible)
DATA_URL = "https://raw.githubusercontent.com/Behnia02/Group_AR/631a8d5f9337e2a4b9351ffb13ca583d28459dc1/HR-Employee-Attrition.csv"

df = pd.read_csv(DATA_URL)

print(f"Dataset loaded from: {DATA_URL}")
print(f"Shape: {df.shape[0]} rows x {df.shape[1]} columns")
display(df.head())
# Out:
# Dataset loaded from: https://raw.githubusercontent.com/Behnia02/Group_AR/631a8d5f9337e2a4b9351ffb13ca583d28459dc1/HR-Employee-Attrition.csv
# Shape: 1470 rows x 35 columns
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# ...

# %% [markdown]
# ### 2.2 Exploratory Data Analysis
#
# The EDA proceeds in three stages: an overview of the dataset structure and quality (2.2.1), descriptive statistics for all variables (2.2.2), and visual exploration of distributions and relationships (2.2.3–2.2.5). Key findings from each stage inform the feature engineering and preprocessing decisions in Section 3.

# %% [markdown]
# #### 2.2.1 Dataset Overview & Data Verification
#
# We first audit the dataset for completeness, data types, and obvious data-quality issues. **Binary string variables** (e.g. `OverTime`, `Gender`) are encoded as integers at this stage to simplify all downstream processing. Columns with zero variance are dropped as they carry no information.

# %%
# Build summary table
summary_table = pd.DataFrame({
    "Total Values": df.count(),
    "Null Values": df.isna().sum(),
    "Unique Values": df.nunique()})

# Display the summary table
summary_table.head(len(summary_table))
# Out:
#                           Total Values  Null Values  Unique Values
# Age                               1470            0             43
# Attrition                         1470            0              2
# BusinessTravel                    1470            0              3
# DailyRate                         1470            0            886
# Department                        1470            0              3
# DistanceFromHome                  1470            0             29
# Education                         1470            0              5
# EducationField                    1470            0              6
# EmployeeCount                     1470            0              1
# EmployeeNumber                    1470            0           1470
# EnvironmentSatisfaction           1470            0              4
# Gender                            1470            0              2
# HourlyRate                        1470            0             71
# ...

# %% [markdown]
# From this table, we can conclude that there is no missing data in the dataset, since all variables have complete records across the 1470 observations.

# %% [markdown]
# Handling of Binary Variables

# %%
# Identify binary variables (exclude PerformanceRating)
binary_vars = [col for col in df.columns
               if (df[col].nunique() == 2 and col != "PerformanceRating")]

# Encode binary variables: Yes/No → 1/0, Male/Female → 1/0
df = df.copy()
df["Attrition_Flag"] = df["Attrition"].map({"Yes": 1, "No": 0})
df["OverTime_Flag"]  = df["OverTime"].map({"Yes": 1, "No": 0})
df["Gender_Flag"]    = df["Gender"].map({"Male": 1, "Female": 0})

# Preview: original strings alongside encoded flags
display(df[["Attrition", "Attrition_Flag", "OverTime", "OverTime_Flag", "Gender", "Gender_Flag"]].head())
# Out:
#   Attrition  Attrition_Flag OverTime  OverTime_Flag  Gender  Gender_Flag
# 0       Yes               1      Yes              1  Female            0
# 1        No               0       No              0    Male            1
# 2       Yes               1      Yes              1    Male            1
# 3        No               0      Yes              1  Female            0
# 4        No               0       No              0    Male            1

# %% [markdown]
# From this point on, **Attrition** is stored as numeric (0 = No, 1 = Yes) for all subsequent analysis and modeling. The same 0/1 encoding applies to OverTime and Gender after the next step (drop originals and rename).
#
# **Note on PerformanceRating:** Although `PerformanceRating` has only 2 unique values in this dataset (3 and 4), it was excluded from binary encoding because it is an ordinal rating scale (originally 1–4), not a categorical flag like Yes/No or Male/Female. The near-zero variance means it carries limited predictive signal for attrition, but it is retained as a numerical variable for completeness.

# %%
#Drop original categorical columns after encoding
df = df.drop(columns=["Attrition", "OverTime", "Gender"])

#Renaming encoded columns to original names for clarity
df = df.rename(columns={
    "Attrition_Flag": "Attrition",
    "OverTime_Flag": "OverTime",
    "Gender_Flag": "Gender"
})

# %%
#Look for duplicates
print("Duplicates:", df.duplicated().sum())
# Out:
# Duplicates: 0

# %%
## Redundant columns: Variables with only one unique value

one_unique_vars = summary_table[summary_table["Unique Values"] == 1].index.tolist()
print(one_unique_vars)
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
# Drop the columns with just one unique value and EmployeeNumber (ID variable)
df = df.drop(columns=["EmployeeCount", "Over18", "StandardHours", "EmployeeNumber"], errors="ignore")

# Drop redundant columns with the same sematic meaning
df = df.drop(columns=["DailyRate", "HourlyRate"], errors="ignore")

# %%
#Checking for missing values
if df.isnull().values.any():
    print("There are missing values in the dataset.")
else:
    print("No missing values found")
# Out:
# No missing values found

# %%
#Sanity check
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Age     BusinessTravel              Department  DistanceFromHome  \
# 0   41      Travel_Rarely                   Sales                 1
# 1   49  Travel_Frequently  Research & Development                 8
# 2   37      Travel_Rarely  Research & Development                 2
# 3   33  Travel_Frequently  Research & Development                 3
# 4   27      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  JobInvolvement  \
# 0          2  Life Sciences                        2               3
# 1          1  Life Sciences                        3               2
# 2          2          Other                        4               2
# 3          4  Life Sciences                        4               3
# 4          1        Medical                        1               3
#
#    JobLevel                JobRole  JobSatisfaction MaritalStatus  \
# 0         2        Sales Executive                4        Single
# ...

# %%
# TARGET
target = "Attrition"

# Feature lists for EDA (Section 2.2); final modeling features are defined in Section 3.5.

# CATEGORICAL VARIABLES (Nominal)
categorical_vars = [
    "BusinessTravel",
    "Department",
    "EducationField",
    "JobRole",
    "MaritalStatus"
]

# ORDINAL / DISCRETE NUMERICAL VARIABLES
# Likert-scale and low-cardinality ordered variables
ordinal_vars = [
    "Education",
    "EnvironmentSatisfaction",
    "JobInvolvement",
    "JobLevel",
    "JobSatisfaction",
    "RelationshipSatisfaction",
    "StockOptionLevel",
    "TrainingTimesLastYear",
    "WorkLifeBalance"
]

# CONTINUOUS / HIGH-CARDINALITY NUMERICAL VARIABLES
continuous_vars = [
    "Age",
    "DistanceFromHome",
    "MonthlyIncome",
    "MonthlyRate",
    "NumCompaniesWorked",
    "PercentSalaryHike",
    "TotalWorkingYears",
    "YearsAtCompany",
    "YearsInCurrentRole",
    "YearsSinceLastPromotion",
    "YearsWithCurrManager"
]

# Combined list for correlation analysis and bivariate plots
numerical_vars = ordinal_vars + continuous_vars

# %% [markdown]
# Variables can also be grouped thematically for interpretation:
#
# - **Demographics:** Age, Gender, MaritalStatus, Education, EducationField, DistanceFromHome
# - **Compensation & financial incentives:** MonthlyIncome, MonthlyRate, PercentSalaryHike, StockOptionLevel, JobLevel
# - **Job structure & role:** Department, JobRole, BusinessTravel, OverTime, JobInvolvement
# - **Career progression & tenure:** TotalWorkingYears, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, NumCompaniesWorked, TrainingTimesLastYear
# - **Workplace satisfaction & environment:** JobSatisfaction, EnvironmentSatisfaction, RelationshipSatisfaction, WorkLifeBalance
#
# All EDA plots and tables in Section 3 use the type-based lists above (categorical_vars and numerical_vars).

# %%
# Metadata table based on current df only

def infer_var_type(series):
    if pd.api.types.is_numeric_dtype(series):
        if series.nunique() == 2:
            return "Binary"
        return "Numerical"
    return "Categorical"

# Optional short descriptions for common columns (only used if present in df)
descriptions = {
    "Age": "Employee age in years",
    "Attrition": "Binary target: attrition",
    "BusinessTravel": "Frequency of business travel",
    "Department": "Department of the employee",
    "DistanceFromHome": "Distance from home to office",
    "Education": "Education level (1-5)",
    "EducationField": "Field of education",
    "EnvironmentSatisfaction": "Satisfaction with work environment (1-4)",
    "Gender": "Binary gender flag",
    "JobInvolvement": "Job involvement (1-4)",
    "JobLevel": "Job hierarchy level",
    "JobRole": "Role or position in company",
    "JobSatisfaction": "Job satisfaction (1-4)",
    "MaritalStatus": "Marital status of employee",
    "MonthlyIncome": "Monthly salary",
    "MonthlyRate": "Monthly rate for payroll purposes",
    "NumCompaniesWorked": "Number of previous companies worked",
    "OverTime": "Binary overtime flag",
    "PercentSalaryHike": "Percentage salary increase",
    "RelationshipSatisfaction": "Relationship satisfaction (1-4)",
    "StockOptionLevel": "Stock option level",
    "TotalWorkingYears": "Total years of work experience",
    "TrainingTimesLastYear": "Number of trainings attended last year",
    "WorkLifeBalance": "Work-life balance rating (1-4)",
    "YearsAtCompany": "Years spent at current company",
    "YearsInCurrentRole": "Years spent in current role",
    "YearsSinceLastPromotion": "Years since last promotion",
    "YearsWithCurrManager": "Years working with current manager"
}

# Build metadata table for all columns in df
metadata_df = pd.DataFrame([
    [col, str(df[col].dtype), infer_var_type(df[col]), descriptions.get(col, "-")]
    for col in df.columns
], columns=["Variable Name", "Data Type", "Variable Type", "Description"])

metadata_styled = (
    metadata_df.style
    .set_properties(**{'border': '1px solid black', 'padding': '4px'})
    .set_table_styles([{
        'selector': 'th',
        'props': [('background-color', '#d3d3d3'),
                  ('color', 'black'),
                  ('font-weight', 'bold'),
                  ('text-align', 'center')]
    }])
    .hide(axis="index")
)

metadata_styled
# Out:
# <style type="text/css">
# #T_4321f th {
#   background-color: #d3d3d3;
#   color: black;
#   font-weight: bold;
#   text-align: center;
# }
# ...

# %% [markdown]
# #### 2.2.2 Descriptive Statistics
#
# Summary statistics (mean, median, mode, standard deviation, min/max) are computed for all numeric variables. This step surfaces the **class imbalance** in the target variable and highlights continuous variables with high skewness that may benefit from log-transformation in Section 3.

# %%
# Descriptive statistics for numeric variables (including median + mode), rounded to 2 decimals
num_cols = df.select_dtypes(include="number").columns.tolist()

numeric_summary = (
    df[num_cols]
    .agg([
        "count",
        "mean",
        "std",
        "min",
        lambda s: s.quantile(0.25),
        "median",
        lambda s: s.mode().iloc[0] if not s.mode().empty else np.nan,
        lambda s: s.quantile(0.75),
        "max"
    ])
    .T
)

numeric_summary.columns = ["count", "mean", "std", "min", "25%", "median", "mode", "75%", "max"]
numeric_summary = numeric_summary.round(2)

numeric_summary
# Out:
#                            count      mean      std     min     25%   median  \
# Age                       1470.0     36.92     9.14    18.0    30.0     36.0
# DistanceFromHome          1470.0      9.19     8.11     1.0     2.0      7.0
# Education                 1470.0      2.91     1.02     1.0     2.0      3.0
# EnvironmentSatisfaction   1470.0      2.72     1.09     1.0     2.0      3.0
# JobInvolvement            1470.0      2.73     0.71     1.0     2.0      3.0
# JobLevel                  1470.0      2.06     1.11     1.0     1.0      2.0
# JobSatisfaction           1470.0      2.73     1.10     1.0     2.0      3.0
# MonthlyIncome             1470.0   6502.93  4707.96  1009.0  2911.0   4919.0
# MonthlyRate               1470.0  14313.10  7117.79  2094.0  8047.0  14235.5
# NumCompaniesWorked        1470.0      2.69     2.50     0.0     1.0      2.0
# PercentSalaryHike         1470.0     15.21     3.66    11.0    12.0     14.0
# ...

# %% [markdown]
# **Target Distribution:** The dataset contains 1,470 employees of whom approximately 16% left the company (237 employees). This means the dataset is imbalanced — roughly 5 non-leavers for every leaver. This imbalance is not severe enough to make the problem intractable, but it shapes every modeling decision that follows: it motivates the use of class_weight="balanced" in Logistic Regression, the choice of ROC-AUC and F1 as evaluation metrics over raw accuracy, and the stratified train/test split in Section 3.6.

# %% [markdown]
# **Summary:** The table above covers all numeric variables including the target (Attrition). Mean of Attrition (0.16) is the attrition rate. Continuous variables such as MonthlyIncome and YearsAtCompany show right skew (mean > median). These patterns motivate log transformation and feature engineering in Section 3.

# %% [markdown]
# The following three subsections explore variable distributions univariately, then in relation to the target, then jointly across multiple features.

# %% [markdown]
# #### 2.2.3 Univariate Analysis
#
# Each variable is examined in isolation to understand its distribution, range, and shape. **Categorical variables** are shown as frequency bar charts; **ordinal variables** as bar charts of rating distributions; **continuous variables** as histograms with KDE overlays, Q-Q plots, and log-transformed versions to assess normality.

# %% [markdown]
# **Categorical Variables**

# %%
# number of categorical variables
n_plots = len(categorical_vars)

# number of columns per row (you can change this)
n_cols = 3

# compute required number of rows
n_rows = math.ceil(n_plots / n_cols)

# automatically generate enough colors
colors = sns.color_palette("tab10", n_plots)

# create subplot grid
fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows))

# flatten axes (important when rows > 1)
axes = axes.flatten()

# loop through each categorical variable and plot
for i, col in enumerate(categorical_vars):
    
    # calculate absolute and relative frequencies
    freq_abs = df[col].value_counts()
    freq_rel = df[col].value_counts(normalize=True) * 100

    # bar plot
    sns.barplot(
        x=freq_abs.index,
        y=freq_abs.values,
        ax=axes[i],
        color=colors[i],
        width=0.5
    )

    # formatting (use descriptions from Section 2.5 metatable when available)
    max_val = freq_abs.values.max()
    lab = descriptions.get(col, col)
    axes[i].set_title(f"Distribution of {lab}", fontsize=12)
    axes[i].set_ylabel("Absolute Frequency")
    axes[i].set_xlabel(lab)
    axes[i].tick_params(axis="x", rotation=45)
    plt.setp(axes[i].get_xticklabels(), ha="right")
    axes[i].set_ylim(0, max_val * 1.15)

    # add relative frequency labels
    for j, val in enumerate(freq_abs.values):
        axes[i].text(
            j,
            val + max_val*0.05,
            f"{freq_rel.values[j]:.1f}%",
            ha="center",
            va="bottom",
            fontsize=9
        )

# remove unused subplot axes
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary:** Most employees are in Research & Development; business travel is mostly "Rarely"; Life Sciences and Medical dominate EducationField; Sales Executive and Research Scientist are the most common job roles; MaritalStatus is spread across Single, Married, and Divorced. These distributions inform the class balance for categorical predictors used in modeling.

# %% [markdown]
#  **Numerical Variables**

# %%
# Frequency barplots for ORDINAL variables only.
# Continuous variables are covered by histograms in the section below.
# Ordinal variables are grouped thematically to reduce visual fatigue.

satisfaction_vars = [
    "EnvironmentSatisfaction",
    "JobSatisfaction",
    "RelationshipSatisfaction",
    "WorkLifeBalance",
    "JobInvolvement"
]
job_structure_vars = [
    "Education",
    "JobLevel",
    "StockOptionLevel",
    "TrainingTimesLastYear"
]

def plot_ordinal_group(var_list, group_title, palette="Blues_d"):
    n_plots = len(var_list)
    n_cols = min(3, n_plots)
    n_rows = math.ceil(n_plots / n_cols)
    colors = sns.color_palette(palette, n_plots)

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows))
    axes = axes.flatten() if n_plots > 1 else [axes]

    for i, col in enumerate(var_list):
        counts = df[col].value_counts().sort_index()
        pct = counts / counts.sum() * 100
        axes[i].bar(counts.index.astype(str), pct.values, color=colors[i])
        lab = descriptions.get(col, col)
        axes[i].set_title(lab)
        axes[i].set_xlabel("Rating")
        axes[i].set_ylabel("% of Employees")
        for x, v in zip(range(len(counts)), pct.values):
            axes[i].text(x, v + 0.3, f"{v:.1f}%", ha="center", fontsize=8)

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    fig.suptitle(group_title, fontsize=13, fontweight="bold", y=1.01)
    plt.tight_layout()
    plt.show()

plot_ordinal_group(satisfaction_vars, "Satisfaction & Involvement Ratings")
plot_ordinal_group(job_structure_vars, "Job Structure Ratings", palette="Oranges_d")

# %% [markdown]
# **Univariate Boxplots (Ordinal Variables)**
#
# The plots below summarise the spread of each ordinal rating variable. Continuous variables are examined in more detail in the dedicated continuous-variable section with histograms and Q-Q plots.

# %%
# Univariate boxplots for ORDINAL variables only.
# (Continuous variables have dedicated histogram + Q-Q treatment below;
#  bivariate boxplots stratified by Attrition appear in Section 3.2.3.2.)

n_plots = len(ordinal_vars)
n_cols = 3
n_rows = math.ceil(n_plots / n_cols)
colors = sns.color_palette("tab10", n_plots)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 3.5 * n_rows))
axes = axes.flatten()

for i, col in enumerate(ordinal_vars):
    sns.boxplot(y=df[col], ax=axes[i], width=0.4, color=colors[i])
    lab = descriptions.get(col, col)
    axes[i].set_title(f"Boxplot of {lab}")
    axes[i].set_xlabel("")
    axes[i].set_ylabel(lab)

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Continuous Variables**

# %%
# Histograms + KDEs for continuous variables (raw, untransformed)

n_vars = len(continuous_vars)
colors = sns.color_palette("tab10", n_vars)

fig, axes = plt.subplots(n_vars, 2, figsize=(12, 4 * n_vars))
if n_vars == 1:
    axes = [axes]

for i, col in enumerate(continuous_vars):
    x = df[col].dropna()
    color = colors[i]
    lab = descriptions.get(col, col)

    # Histogram
    sns.histplot(x, bins=30, ax=axes[i][0], color=color, kde=False)
    axes[i][0].set_title(f"Histogram: {lab}")
    axes[i][0].set_xlabel(lab)
    axes[i][0].set_ylabel("Count")

    # KDE
    sns.kdeplot(x, ax=axes[i][1], color=color, fill=True, alpha=0.4)
    axes[i][1].set_title(f"Density: {lab}")
    axes[i][1].set_xlabel(lab)
    axes[i][1].set_ylabel("Density")

plt.tight_layout()
plt.show()

# %%
# Calculate skewness and kurtosis for continuous variables
results = []

for col in continuous_vars:
    x = df[col].dropna()
    results.append({
        "Variable": col,
        "Skewness": x.skew(),
        "Kurtosis": x.kurt()   # pandas = excess kurtosis (normal ≈ 0)
    })

skew_kurt_df = pd.DataFrame(results).sort_values("Variable").reset_index(drop=True).round(2)
skew_kurt_df
# Out:
#                    Variable  Skewness  Kurtosis
# 0                       Age      0.41     -0.40
# 1          DistanceFromHome      0.96     -0.22
# 2             MonthlyIncome      1.37      1.01
# 3               MonthlyRate      0.02     -1.21
# 4        NumCompaniesWorked      1.03      0.01
# 5         PercentSalaryHike      0.82     -0.30
# 6         TotalWorkingYears      1.12      0.92
# 7            YearsAtCompany      1.76      3.94
# 8        YearsInCurrentRole      0.92      0.48
# 9   YearsSinceLastPromotion      1.98      3.61
# 10     YearsWithCurrManager      0.83      0.17

# %%
# Q-Q plots for continuous variables
n_plots = len(continuous_vars)
n_cols = 3
n_rows = math.ceil(n_plots / n_cols)

colors = sns.color_palette("tab10", n_plots)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows))
axes = axes.flatten()

for i, col in enumerate(continuous_vars):
    x = df[col].dropna().values
    color = colors[i]

    # theoretical quantiles (osm) and ordered responses (osr)
    (osm, osr), (slope, intercept, r) = stats.probplot(x, dist="norm")

    # scatter points
    axes[i].scatter(osm, osr, color=color, s=18)

    # fitted reference line
    line_x = np.array([osm.min(), osm.max()])
    line_y = slope * line_x + intercept
    axes[i].plot(line_x, line_y, color=color, linewidth=2)

    axes[i].set_title(f"Q-Q Plot: {col}")
    axes[i].set_xlabel("Theoretical Quantiles")
    axes[i].set_ylabel("Ordered Values")

# remove empty subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Log-transform histograms + KDEs for continuous variables (handle skewness)

n_vars = len(continuous_vars)

fig, axes = plt.subplots(n_vars, 2, figsize=(12, 4 * n_vars))

# Fix for single variable case
if n_vars == 1:
    axes = [axes]

colors = sns.color_palette("tab10", n_vars)

for i, col in enumerate(continuous_vars):
    
    x = df[col].dropna()
    log_x = np.log1p(x)  # log1p used — safe for zero values (log1p(0)=0, log(0)=-inf)
    color = colors[i]
    
    # ---- Histogram (left) ----
    sns.histplot(
        log_x,
        bins=30,
        ax=axes[i][0],
        color=color
    )
    axes[i][0].set_title(f"Histogram of log1p({col})")
    axes[i][0].set_xlabel(f"log1p({col})")
    axes[i][0].set_ylabel("Frequency")
    
    # ---- KDE (right) ----
    sns.kdeplot(
        log_x,
        ax=axes[i][1],
        fill=True,
        color=color
    )
    axes[i][1].set_title(f"Kernel Density Plot of log1p({col})")
    axes[i][1].set_xlabel(f"log1p({col})")
    axes[i][1].set_ylabel("Density")

plt.tight_layout()
plt.show()

# %%
results_log = []

for col in continuous_vars:
    x = df[col].dropna()
    log_x = np.log1p(x)  # log1p used — safe for zero values

    results_log.append({
        "Variable": col,
        "Log Skewness": log_x.skew(),
        "Log Kurtosis": log_x.kurt()
    })

log_stats_df = pd.DataFrame(results_log).round(2)
log_stats_df
# Out:
#                    Variable  Log Skewness  Log Kurtosis
# 0                       Age         -0.14         -0.35
# 1          DistanceFromHome         -0.03         -1.22
# 2             MonthlyIncome          0.29         -0.70
# 3               MonthlyRate         -0.82         -0.24
# 4        NumCompaniesWorked          0.09         -0.92
# 5         PercentSalaryHike          0.51         -0.81
# 6         TotalWorkingYears         -0.62          0.52
# 7            YearsAtCompany         -0.21         -0.28
# 8        YearsInCurrentRole         -0.38         -0.79
# 9   YearsSinceLastPromotion          0.72         -0.60
# 10     YearsWithCurrManager         -0.36         -0.91

# %% [markdown]
# **Note on squared transformation:** A squared transformation was tested for the continuous variables; log1p was chosen for the pipeline (Section 3.4) as it gave better skewness reduction and handles zeros. Plots and tables for the squared transformation are omitted.

# %% [markdown]
# #### 2.2.4 Bivariate Analysis
#
# Variables are examined in relation to the **target variable (Attrition)**. Stratified boxplots show how numerical features differ between leavers and stayers. **Spearman correlation** ranks the strength of monotonic associations with Attrition. Scatter plots visualise continuous-variable relationships.

# %% [markdown]
# **Stratified Boxplots**

# %%
# Stratified boxplots: each numerical variable vs Attrition (0 = No, 1 = Yes)
n_plots = len(numerical_vars)
n_cols = 3
n_rows = math.ceil(n_plots / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5 * n_cols, 4 * n_rows))
axes = axes.flatten()

for i, col in enumerate(numerical_vars):
    sns.boxplot(
        x=df["Attrition"],
        y=df[col],
        ax=axes[i],
        palette=["#4C72B0", "#DD8452"]   # 0 = blue (Stay), 1 = orange (Leave)
    )
    lab = descriptions.get(col, col)
    axes[i].set_title(f"Relationship between {lab} and Attrition")
    axes[i].set_xlabel("Attrition (0 = Stay, 1 = Leave)")
    axes[i].set_ylabel(lab)

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Correlation with Attrition**

# %%
# Compute Spearman correlations
correlations = []

for col in numerical_vars:
    corr = df[[col, "Attrition"]].corr(method="spearman").iloc[0, 1]
    correlations.append({
        "Variable": col,
        "Spearman Correlation": corr
    })

# Create DataFrame
spearman_df = pd.DataFrame(correlations)

# Sort by absolute correlation (strongest at top)
spearman_df = spearman_df.reindex(
    spearman_df["Spearman Correlation"].abs().sort_values(ascending=False).index
)

# ---- Visualization ----
plt.figure(figsize=(8, 6))

sns.barplot(
    data=spearman_df,
    x="Spearman Correlation",
    y="Variable",
    palette="coolwarm"
)

plt.axvline(0, color="black", linewidth=1)
plt.title("Spearman Correlation with Attrition")
plt.xlabel("Spearman Correlation")
plt.ylabel("Feature")

plt.tight_layout()
plt.show()

# %% [markdown]
# **Summary:** Spearman correlation with Attrition (above) shows which numeric features associate most with leaving. OverTime and JobLevel are among the stronger correlates. This motivates keeping these in the model and supports the same correlation check for engineered features in Section 3.3.

# %% [markdown]
# **Scatterplots**

# %%
n_plots = len(continuous_vars)
n_cols = 3
n_rows = math.ceil(n_plots / n_cols)

fig, axes = plt.subplots(n_rows, n_cols, figsize=(5*n_cols, 4*n_rows))
axes = axes.flatten()

for i, col in enumerate(continuous_vars):
    
    sns.stripplot(
        x=df["Attrition"],
        y=df[col],
        ax=axes[i],
        jitter=True,
        alpha=0.4,
        palette=["#4C72B0", "#DD8452"]  # 0 = No, 1 = Yes (consistent with other Attrition plots)
    )
    
    lab = descriptions.get(col, col)
    axes[i].set_title(f"Relationship between {lab} and Attrition")
    axes[i].set_xlabel("Attrition")
    axes[i].set_ylabel(lab)

# remove empty axes
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 2.2.5 Multivariate Analysis & Correlation
#
# The full **Spearman correlation matrix** reveals collinearity between numerical predictors, particularly among tenure-related variables. **PCA** is used as an exploratory tool to visualise how well the feature space separates leavers from stayers in two dimensions. Interaction heatmaps examine how pairs of top-correlated features jointly relate to attrition rates.

# %% [markdown]
# **Correlation Matrix Heatmap**

# %%
corr = df[numerical_vars].corr(method="spearman")

# mask upper triangle for readability
mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(12, 10))
sns.heatmap(
    corr,
    mask=mask,
    cmap="coolwarm",
    center=0,
    linewidths=0.5,
    cbar_kws={"label": "Spearman correlation"}
)

plt.title("Spearman Correlation Matrix (Predictors)")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Principal Component Analysis (PCA)**
#
# PCA is used here only as an exploratory tool on the original numeric variables (before log1p and without engineered features). The final model (Section 3) uses a different feature space: log1p-transformed variables and engineered features as defined in Section 3.5.

# %%
# separate variable names to avoid overwriting X, y used in Section 3.6
X_pca_input = df[numerical_vars].dropna()
y_pca = df.loc[X_pca_input.index, "Attrition"]

# scale for PCA only — not part of the modeling pipeline
scaler_pca = StandardScaler()
X_pca_scaled = scaler_pca.fit_transform(X_pca_input)

# PCA
pca = PCA()
X_pca = pca.fit_transform(X_pca_scaled)

# --- 1) Explained variance ratio plot ---
plt.figure(figsize=(8, 4))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker="o")
plt.title("PCA: Cumulative Explained Variance")
plt.xlabel("Number of components")
plt.ylabel("Cumulative explained variance ratio")
plt.ylim(0, 1.01)
plt.tight_layout()
plt.show()

# --- 2) 2D projection (PC1 vs PC2) ---
pca2 = PCA(n_components=2)
X_pca2 = pca2.fit_transform(X_pca_scaled)

# Consistent Attrition colors: 0 = blue, 1 = orange (same as bivariate boxplots)
plt.figure(figsize=(7, 5))
sns.scatterplot(x=X_pca2[:, 0], y=X_pca2[:, 1], hue=y_pca, alpha=0.6, palette=["#4C72B0", "#DD8452"])
plt.title("PCA Projection: PC1 vs PC2 (coloured by Attrition)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interaction Effects**
#
# To explore whether attrition depends on combinations of predictors rather than on single variables in isolation, we examine interaction heatmaps for selected feature pairs. For each pair of variables, the data are divided into quantile-based bins, and each cell in the heatmap reports the mean attrition rate for employees in that combination of bins. Because attrition is encoded as 0 = no attrition and 1 = attrition, the cell values can be interpreted as target rates within each subgroup.
#
# These heatmaps provide a descriptive view of how attrition varies across combinations of predictors and help reveal non-linear or interaction-like patterns that may not be visible from simple one-variable summaries or pairwise correlations alone. In the plots below, lighter cells indicate higher attrition rates, while darker cells indicate lower attrition rates. Some interactions should be interpreted cautiously, particularly where variables are structurally related or where certain combinations are sparsely represented. The purpose of this analysis is exploratory: it helps identify potentially important subgroup patterns and informs feature engineering, but it does not by itself establish statistically significant interaction effects.

# %%
def interaction_heatmap(df, x_col, y_col, target="Attrition", q=5):
    tmp = df[[x_col, y_col, target]].dropna().copy()

    # map target if it's text (adjust if your labels differ)
    if tmp[target].dtype == "object":
        tmp[target] = tmp[target].map({"No Attrition": 0, "Attrition": 1})

    # quantile bins
    tmp["x_bin"] = pd.qcut(tmp[x_col], q=q, duplicates="drop")
    tmp["y_bin"] = pd.qcut(tmp[y_col], q=q, duplicates="drop")

    # target rate pivot
    pivot = tmp.pivot_table(index="y_bin", columns="x_bin", values=target, aggfunc="mean")

    plt.figure(figsize=(10, 6))
    sns.heatmap(pivot, cmap="viridis", annot=True, fmt=".2f")
    plt.title(f"Interaction (Target Rate) Heatmap: {y_col} vs {x_col}\nCells = mean({target})")
    plt.xlabel(f"{x_col} (quantile bins)")
    plt.ylabel(f"{y_col} (quantile bins)")
    plt.tight_layout()
    plt.show()

# %%
# Attrition is already numeric 0/1 — compute correlations directly
tmp = df[numerical_vars + ["Attrition"]].dropna().copy()

scores = []
for col in numerical_vars:
    scores.append((col, tmp[[col, "Attrition"]].corr(method="spearman").iloc[0, 1]))

scores_df = pd.DataFrame(scores, columns=["Variable", "Spearman"]).assign(
    abs_spearman=lambda d: d["Spearman"].abs()
)
top_features = scores_df.sort_values("abs_spearman", ascending=False)["Variable"].head(4).tolist()

# plot pairwise interaction heatmaps for top 4 most correlated features
for a, b in itertools.combinations(top_features, 2):
    interaction_heatmap(df, a, b, target="Attrition", q=5)

# %% [markdown]
# **Heatmap 1 — MonthlyIncome × TotalWorkingYears**
# Attrition is highest among employees with both low monthly income and low total working years, indicating that early-career, lower-paid employees are the most vulnerable subgroup. Across the grid, attrition generally declines as either income or experience increases, with the gradient appearing steeper for MonthlyIncome, suggesting that income exerts the stronger influence on attrition. A few cells remain elevated despite higher income, which may reflect subgroup-specific instability rather than a uniform linear relationship. Overall, this heatmap suggests that MonthlyIncome and TotalWorkingYears each contribute relevant information and may interact in non-uniform ways.
#
# **Heatmap 2 — YearsAtCompany × TotalWorkingYears**
# Employees with both short company tenure and limited total work experience show the highest attrition. Attrition decreases noticeably once employees spend more time at the company, even at similar levels of total work experience. This indicates that organizational tenure may matter beyond overall career length. The pattern motivated exploration of TenureRatio as a feature capturing company tenure relative to total career experience.
#
# **Heatmap 3 — JobLevel × TotalWorkingYears**
# Attrition is concentrated among lower job levels with limited experience, while employees at higher job levels and with moderate or high experience show consistently lower attrition. This suggests that JobLevel contains information not fully explained by experience alone. Rather than being absorbed into another engineered variable, JobLevel appears to deserve consideration as a standalone predictor.
#
# **Heatmap 4 — YearsAtCompany × MonthlyIncome**
# The highest attrition again appears among employees with both short tenure and low income, reinforcing the broader pattern that newer and lower-paid employees are at greater risk of leaving. Attrition generally falls as tenure and income rise, although some mid-range cells show local variation. This suggests that the relationship between income, tenure, and attrition is not purely additive and may differ across employee subgroups.
#
# **Heatmap 5 — JobLevel × MonthlyIncome**
# This heatmap should be interpreted with caution, as MonthlyIncome and JobLevel are structurally related, leading to sparse or missing combinations. Attrition is highest among lower job levels with lower income and generally decreases for higher levels and income. Some mid-range cells show elevated attrition, but these are based on few observations and should not be overinterpreted. Overall, both variables appear relevant but partially overlapping, so this plot is treated as exploratory and only provided limited motivation for testing IncomeLevelRatio.
#
# **Heatmap 6 — JobLevel × YearsAtCompany**
# Attrition is highest among junior employees with very short tenure and falls substantially for employees who are either more senior, longer tenured, or both. This suggests that role seniority and company tenure provide partly distinct information and jointly help explain retention patterns.
#
# Taken together, the interaction heatmaps suggest that attrition is concentrated in specific employee subgroups rather than being uniform across the workforce. These patterns provided exploratory motivation for testing engineered features such as TenureRatio and IncomeLevelRatio, since both were designed to capture relationships that appear non-uniform in the visual analysis. However, the heatmaps are descriptive rather than confirmatory, so the decision to retain engineered features should ultimately rest on downstream model performance and interpretability.

# %% [markdown]
# **Key findings from EDA and link to the pipeline:**
#
# - **Target imbalance:** Attrition is approximately 16% (encoded as 0/1), indicating a moderately imbalanced target. This is addressed later in the modelling pipeline through the class imbalance strategy and, where appropriate, the use of class_weight="balanced".
# - **Skewness of continuous variables:** Variables such as MonthlyIncome, DistanceFromHome, YearsSinceLastPromotion, YearsAtCompany, and TotalWorkingYears are right-skewed. This informed the use of log1p transformations in the preprocessing stage.
# - **Correlation with Attrition:** Spearman correlations were used to identify the numerical variables with the strongest univariate association with attrition and were later revisited to evaluate engineered features.
# - **Correlation structure among predictors:** The correlation heatmap highlights dependence among several predictors, especially tenure and experience-related variables, which informed later interpretation and feature engineering.
# - **PCA:** PCA was used for exploratory structure analysis only. The final model uses the original and engineered feature set rather than PCA components.
# - **Interaction heatmaps:** Interaction heatmaps were used to explore how the numerical variables most strongly associated with attrition behave jointly. These plots provided descriptive, exploratory support for testing features such as TenureRatio and IncomeLevelRatio, while final retention decisions were left to downstream model performance and interpretability.

# %% [markdown]
# ---
#
# ## 3. Data Preparation
#
# The EDA revealed several characteristics of the data that must be addressed before modelling: skewed continuous variables, multicollinear tenure features, and a significant class imbalance. This section applies targeted transformations — feature engineering, log-transformation, train/test splitting, and preprocessing pipelines — to produce a clean, model-ready dataset.

# %% [markdown]
# Now that EDA is done, this section prepares the data before running the Logistic Regression model. We engineer some new features, apply log transformations to skewed variables, split the data into training and test sets, scale and encode the features, and handle the class imbalance in the target variable.
#
# The pipeline covers the following steps: imports, feature engineering, verification of engineered features, log transformation, defining the final feature sets, train/test split, preprocessing (scaling and encoding), class imbalance handling, assembling the full pipeline, and a final sanity check.

# %% [markdown]
# All library imports are consolidated in the **Imports** cell in Section 2.1. The cells below use those imports directly.

# %%
# All sklearn imports are consolidated in the Imports cell at the top of this notebook.

# %% [markdown]
# ### 3.1 Feature Engineering
#
# Raw variables are combined into new composite features that capture higher-level patterns less susceptible to multicollinearity. For example, `TenureRatio` captures relative seniority within total career length; `PromotionLag` captures time since last promotion; `IncomeLevelRatio` normalises salary within job level.

# %% [markdown]
# In this section we created new variables from the ones already existing so they better capture the underlying signal.
#
# We created four composite features based on the following reasoning:
#
# | Feature | Formula | What it captures |
# |---|---|---|
# | TenureRatio | YearsAtCompany / (TotalWorkingYears + 1) | How much of the employee's total career has been spent here. A low ratio signals job-hopping is a known attrition predictor. |
# | PromotionLag | YearsSinceLastPromotion / (YearsInCurrentRole + 1) | Stagnation: stuck in the same role without promotion. High values suggest frustration. |
# | IncomeLevelRatio | MonthlyIncome / (JobLevel × 1000) | Whether the employee is fairly paid for their seniority. A ratio well below 1 signals underpayment relative to job level. |
# | SatisfactionIndex | Mean of 4 satisfaction scores | A composite wellbeing score. EDA showed all four satisfaction variables correlate with attrition so combining them into one index reduces noise and multicollinearity. |

# %%
df = df.copy()  

df["TenureRatio"] = df["YearsAtCompany"] / (df["TotalWorkingYears"] + 1)

df["PromotionLag"] = df["YearsSinceLastPromotion"] / (df["YearsInCurrentRole"] + 1)

df["IncomeLevelRatio"] = df["MonthlyIncome"] / (df["JobLevel"] * 1000)

# # SatisfactionIndex: composite of four satisfaction variables, reduces multicollinearity
df["SatisfactionIndex"] = df[[
    "JobSatisfaction",
    "EnvironmentSatisfaction",
    "RelationshipSatisfaction",
    "WorkLifeBalance"
]].mean(axis=1)

# Descriptive statistics for engineered features
df[["TenureRatio", "PromotionLag", "IncomeLevelRatio", "SatisfactionIndex"]].describe().round(2)
# Out:
#        TenureRatio  PromotionLag  IncomeLevelRatio  SatisfactionIndex
# count      1470.00       1470.00           1470.00            1470.00
# mean          0.58          0.39              2.97               2.73
# std           0.28          0.63              0.77               0.51
# min           0.00          0.00              1.01               1.00
# 25%           0.37          0.00              2.39               2.50
# 50%           0.64          0.20              2.86               2.75
# 75%           0.83          0.67              3.48               3.00
# max           0.98          7.00              5.00               4.00

# %% [markdown]
# All 1470 rows are present with no missing values. TenureRatio has a mean of 0.58, meaning on average employees have spent about 58% of their career at this company. PromotionLag has a max of 7.0 indicating some employees have been stuck in the same role for a long time without promotion. IncomeLevelRatio averages 2.97, suggesting most employees are paid above the base level for their job level. SatisfactionIndex ranges from 1 to 4 with a mean of 2.73, roughly in the middle of the scale.

# %% [markdown]
# **Feature Verification — Correlation with Attrition**
#
# We use the same Spearman correlation logic as Section 2.2.4 to confirm that the engineered features carry meaningful signal before including them in the final feature set.

# %% [markdown]
# We use the same correlation logic as in Section 2.2.3.2 to assess the signal in the newly engineered features. Before using these features in the model, we verify that they carry a meaningful relationship with the target. We use Spearman correlation (as in EDA) since the new features are not normally distributed.
#
# Expected findings based on domain knowledge:
# - SatisfactionIndex: negative correlation (lower satisfaction = more attrition)
# - PromotionLag: positive correlation (more stagnation = more attrition)
# - TenureRatio: negative correlation (more loyal employees less likely to leave)
# - IncomeLevelRatio: negative correlation (underpaid employees more likely to leave)

# %%
engineered_vars = ["TenureRatio", "PromotionLag", "IncomeLevelRatio", "SatisfactionIndex"]

eng_correlations = []
for col in engineered_vars:
    corr = df[[col, "Attrition"]].corr(method="spearman").iloc[0, 1]
    eng_correlations.append({"Feature": col, "Spearman Correlation": round(corr, 3)})

eng_corr_df = pd.DataFrame(eng_correlations).sort_values(
    "Spearman Correlation", key=abs, ascending=False
)


fig, ax = plt.subplots(figsize=(7, 3))
bar_colors = ["orange" if c < 0 else "blue" for c in eng_corr_df["Spearman Correlation"]]
ax.barh(eng_corr_df["Feature"], eng_corr_df["Spearman Correlation"], color=bar_colors)
ax.axvline(0, color="black", linewidth=0.8)
ax.set_title("Spearman Correlation of Engineered Features with Attrition")
ax.set_xlabel("Spearman Correlation")
plt.tight_layout()
plt.show()

display(eng_corr_df)
# Out:
#              Feature  Spearman Correlation
# 3  SatisfactionIndex                -0.148
# 2   IncomeLevelRatio                -0.113
# 0        TenureRatio                -0.098
# 1       PromotionLag                -0.020

# %% [markdown]
# All four engineered features show a negative correlation with attrition, meaning employees with higher scores on these variables are less likely to leave. SatisfactionIndex has the strongest relationship (-0.148), followed by IncomeLevelRatio (-0.113) and TenureRatio (-0.098). PromotionLag is the weakest (-0.020) but still goes in the expected direction. All features carry some signal so we keep all four in the model.

# %% [markdown]
# ### 3.2 Log Transformation of Skewed Variables
#
# Several continuous variables (`MonthlyIncome`, `DistanceFromHome`, `YearsSinceLastPromotion`, `TotalWorkingYears`, `YearsAtCompany`) showed pronounced right-skew in Section 2.2.3. **Log1p transformation** (`log(1 + x)`) reduces skewness and makes the variable distribution more symmetric, which improves the calibration of Logistic Regression coefficients.

# %% [markdown]
# From the EDA in Section 2.2.3, several continuous variables were confirmed to be right-skewed. We apply a log1p transformation to reduce this skewness, which helps Logistic Regression perform better. We use log1p instead of log because some employees have 0 values, and log(0)is undefined. The original columns are then dropped and replaced entirely by their log versions so there are no duplicates and we don't have twice the same information.

# %%
skewed_vars = [
    "MonthlyIncome",
    "DistanceFromHome",
    "YearsSinceLastPromotion",
    "YearsAtCompany",
    "TotalWorkingYears"

]
for col in skewed_vars:
    df[f"log_{col}"] = np.log1p(df[col])


skew_comparison = pd.DataFrame({
    "Original Skewness": [round(df[col].skew(), 3) for col in skewed_vars],
    "After log1p":       [round(df[f"log_{col}"].skew(), 3) for col in skewed_vars]
}, index=skewed_vars)

# Skewness before and after log1p (closer to 0 = more symmetric, better for Logistic Regression)
display(skew_comparison)

df = df.drop(columns=skewed_vars)
# Out:
#                          Original Skewness  After log1p
# MonthlyIncome                        1.370        0.286
# DistanceFromHome                     0.958       -0.029
# YearsSinceLastPromotion              1.984        0.719
# YearsAtCompany                       1.765       -0.208
# TotalWorkingYears                    1.117       -0.622

# %% [markdown]
# The log1p transformation significantly reduced the skewness of all five variables (see table above). DistanceFromHome and YearsAtCompany are now very close to 0, meaning nearly symmetric. YearsSinceLastPromotion improved the most, dropping from 1.984 to 0.719. After dropping the original skewed columns, the dataframe has 1470 rows and 33 columns. All variables are now much more suitable for Logistic Regression.

# %% [markdown]
# ### 3.3 Final Feature Set Definition
#
# We define three feature lists — **categorical**, **ordinal/numerical**, and **continuous** — that will be passed to the `ColumnTransformer` in Section 3.5. Log-transformed versions of skewed variables replace the originals; redundant variables identified in EDA are excluded.

# %% [markdown]
# Here we define the final list of features that will enter the model. We need to redefine these because the feature lists from Section 2 were for EDA only and don't reflect the changes made in Section 3; the log-transformed columns, the new engineered features, and SatisfactionIndex replacing the four individual satisfaction variables. The categorical features will be one-hot encoded and the numerical features will be scaled.

# %%
TARGET = "Attrition"


categorical_features = [
    "BusinessTravel",
    "Department",
    "EducationField",
    "JobRole",
    "MaritalStatus"
]

# Numerical features; already numeric, will be Standard Scaled
numerical_features = [
    # Binary flags (already 0/1 from Section 2 encoding)
    "OverTime",
    "Gender",
    # Ordinal / Likert-scale variables
    "Education",
    "JobInvolvement",
    "JobLevel",
    "StockOptionLevel",
    "TrainingTimesLastYear",
    # Continuous variables, not skewed, used as-is
    "Age",
    "NumCompaniesWorked",
    "PercentSalaryHike",
    "YearsInCurrentRole",
    "YearsWithCurrManager",
    # Log-transformed versions, originals dropped in Section 3.4
    "log_MonthlyIncome",
    "log_DistanceFromHome",
    "log_YearsSinceLastPromotion",
    "log_YearsAtCompany",
    "log_TotalWorkingYears",
    "TenureRatio",
    "PromotionLag",
    "IncomeLevelRatio",
    "SatisfactionIndex"
]

all_features = categorical_features + numerical_features

# %% [markdown]
# **Note on MonthlyRate:** MonthlyRate is an administrative payroll variable that shows near-zero Spearman correlation with attrition in the EDA (Section 2.2.3.2). It is excluded from the final feature set as it carries no meaningful signal for predicting attrition.

# %% [markdown]
# ### 3.4 Train / Test Split

# %% [markdown]
# We split the data into 80% training and 20% test sets. We use stratify = y to make sure both sets keep the same ~16% attrition rate, and random_state = 42 so the split is reproducible. We split before preprocessing to avoid data leakage; if we scaled the full dataset first, the scaler would have seen the test data, which would make our evaluation results unreliable.

# %%
X = df[all_features]  
y = df[TARGET]        

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42,
    stratify = y        # preserve ~16% attrition rate in both sets
)

# %% [markdown]
# The attrition rate is consistent across all three sets (16.12%, 16.16%, 15.99%), confirming that stratification worked correctly.

# %% [markdown]
# ### 3.5 Preprocessing Pipeline
#
# A **`ColumnTransformer`** applies type-specific transformations in parallel: numerical features are **standardised** (`StandardScaler`); categorical features are **one-hot encoded** (`OneHotEncoder`). The transformer is later composed with each model into a single `Pipeline` object, ensuring that all transformations are fitted only on training data and applied consistently to the test set — preventing data leakage.

# %% [markdown]
# Before feeding the data into the model, we need to apply two transformations. StandardScaler is applied to all numerical features to put them on the same scale, since features with large ranges like MonthlyIncome would otherwise dominate over smaller ones. OneHotEncoder is applied to the categorical features to convert them into binary columns, with drop = "first" to avoid multicollinearity. The ColumnTransformer applies both at the same time and outputs a single feature matrix.

# %%
numeric_transformer = Pipeline(steps=[
    ("scaler", StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ("encoder", OneHotEncoder(
        drop="first",             # avoids perfect multicollinearity in logistic regression
                                  
        handle_unknown="ignore",  
        sparse_output=False       
    ))
])


preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer,     numerical_features),
        ("cat", categorical_transformer, categorical_features)
    ],
    remainder="drop"  
)

# %% [markdown]
# ### 3.6 Class Imbalance — Assessment & Strategy
#
# The target variable is imbalanced (~84% No Attrition, ~16% Attrition). A naïve model that always predicts the majority class would achieve 84% accuracy yet be useless for HR. We address this with **`class_weight="balanced"`** in tree-based and linear models (equivalent to upweighting minority class examples), and visualise the class distribution across training and test sets to confirm stratification was preserved.

# %% [markdown]
# The dataset has around 84% No Attrition and 16% Attrition, which is imbalanced. To handle this we use class_weight = "balanced" in the Logistic Regression, which automatically gives more weight to the minority class during training so the model doesn't just ignore it. We decided against SMOTE since the imbalance is moderate enough that class_weight = "balanced" is sufficient on its own, and using both at the same time would overcorrect for the same problem.

# %%
fig, axes = plt.subplots(1, 2, figsize=(11, 4))

for ax, (split_name, split_y) in zip(axes, [("Train Set", y_train), ("Test Set", y_test)]):
    counts = pd.Series(split_y).value_counts().sort_index()
    bars = ax.bar(
        ["No Attrition (0)", "Attrition (1)"],
        counts.values,
        color=["blue", "orange"],
        edgecolor="white",
        width=0.5
    )
    ax.set_title(f"{split_name} : Class Distribution", fontsize=12, fontweight="bold")
    ax.set_ylabel("Number of Samples")
    ax.set_ylim(0, counts.values.max() * 1.18)
    for bar, val in zip(bars, counts.values):
        ax.text(
            bar.get_x() + bar.get_width() / 2,
            bar.get_height() + 10,
            f"{val}\n({val / len(split_y):.1%})",
            ha="center", va="bottom", fontsize=10
        )

plt.suptitle('Class Imbalance - Addressed via class_weight="balanced" in Logistic Regression',
             fontsize=11, y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# Both sets show a consistent split of around 84% No Attrition and 16% Attrition, confirming that stratification worked correctly. The imbalance is visible but moderate, and will be handled by class_weight="balanced" in the model.

# %% [markdown]
# **Full Pipeline Assembly**
#
# The preprocessor and model are combined into a single `Pipeline` object. This ensures the preprocessing step is always applied before prediction and can be passed as a single estimator to cross-validation and hyperparameter search utilities.

# %% [markdown]
# Here we combine the preprocessor and the model into a single Pipeline object. This keeps everything in one place, prevents data leakage during cross-validation, and makes it easy to swap the model later without changing anything else. We chose Logistic Regression as the first model because it is simple and interpretable, which is useful when explaining results to non-technical stakeholders like HR.

# %%
full_pipeline = Pipeline(steps=[

    ("preprocessor", preprocessor),
 
    # C=1.0 baseline, tuned in Section 5
    # balanced weights for class imbalance
    # higher max_iter for convergence with many features
    
    ("model", LogisticRegression(
        penalty="l2",
        C=1.0,
        class_weight="balanced",
        max_iter=1000,
        random_state=42
    ))
])

# %%
full_pipeline.fit(X_train, y_train)
test_preds = full_pipeline.predict(X_test)

# %% [markdown]
# Sanity check: train and test sets contain no NaNs; the pipeline fits and predicts successfully. Feature counts and class distributions are consistent with the definitions in Sections 3.5 and 3.6.

# %% [markdown]
# ---
#
# ## 4. Modelling
#
# Four model families are trained in sequence, forming a deliberate progression from interpretable to complex: **Logistic Regression** provides a transparent linear baseline; **Random Forest** introduces non-linearity through an ensemble of decision trees; **Gradient Boosting** adds sequential error correction for improved accuracy; and a **Neural Network** explores deep learning as an upper bound on performance. This progression allows us to assess whether added complexity yields meaningful gains for this dataset.
#
# > **Note:** Each subsection covers the model architecture, training, and inline sanity checks (cross-validation AUC, baseline metrics). Full comparative evaluation — metrics tables, ROC curves, and feature importance analysis — is consolidated in Section 5.

# %% [markdown]
# ### 4.1 Logistic Regression
#
# **Logistic Regression** serves as the interpretable linear baseline. Its coefficients directly quantify the log-odds contribution of each feature to the probability of attrition, making it easy to explain to stakeholders. The full preprocessing pipeline (standardisation + one-hot encoding) is included as the first step.

# %% [markdown]
# #### 4.1.1 Baseline Model
#
# The pipeline is fitted with default regularisation (`C=1.0`) and `class_weight="balanced"` to account for the class imbalance. 5-fold cross-validated ROC-AUC on the training set provides an unbiased estimate of generalisation performance before any tuning.

# %%
# 5-fold cross-validated ROC-AUC on training set
cv_scores = cross_val_score(
    full_pipeline, X_train, y_train,
    cv=5,
    scoring="roc_auc",
    n_jobs=-1
)

print(f"CV ROC-AUC scores : {cv_scores.round(4)}")
print(f"Mean CV ROC-AUC   : {cv_scores.mean():.4f}")
print(f"Std CV ROC-AUC    : {cv_scores.std():.4f}")

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, test_preds)

fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Attrition (0)", "Attrition (1)"],
    yticklabels=["No Attrition (0)", "Attrition (1)"],
    linewidths=0.5,
    ax=ax
)
ax.set_xlabel("Predicted Label", fontsize=11)
ax.set_ylabel("True Label", fontsize=11)
ax.set_title("Confusion Matrix – Baseline Logistic Regression",
             fontsize=12, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# Classification Report
print("Classification Report – Baseline Logistic Regression")
print("=" * 55)
print(classification_report(
    y_test, test_preds,
    target_names=["No Attrition (0)", "Attrition (1)"]
))

# ROC-AUC Score
y_prob_baseline  = full_pipeline.predict_proba(X_test)[:, 1]
roc_auc_baseline = roc_auc_score(y_test, y_prob_baseline)

# Precision-Recall AUC — more informative than ROC-AUC under class imbalance
pr_auc_baseline = average_precision_score(y_test, y_prob_baseline)

print(f"ROC-AUC Score        : {roc_auc_baseline:.4f}")
print(f"Precision-Recall AUC : {pr_auc_baseline:.4f}")

# ROC Curve
fpr_b, tpr_b, _ = roc_curve(y_test, y_prob_baseline)

fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(fpr_b, tpr_b, color="blue", lw=2,
        label=f"Baseline LR (AUC = {roc_auc_baseline:.3f})")
ax.plot([0, 1], [0, 1], color="gray", linestyle="--", lw=1,
        label="Random Classifier")

ax.set_xlabel("False Positive Rate", fontsize=11)
ax.set_ylabel("True Positive Rate (Recall)", fontsize=11)
ax.set_title("ROC Curve – Baseline Logistic Regression",
             fontsize=12, fontweight="bold")
ax.legend(loc="lower right", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# #### 4.1.2 Hyperparameter Tuning
#
# The **regularisation strength `C`** controls the trade-off between fitting the training data and keeping coefficients small. A smaller `C` = stronger regularisation. `GridSearchCV` with 5-fold cross-validation searches 10 values spanning four orders of magnitude, optimising ROC-AUC.

# %%
# Define the C parameter grid
param_grid = {
    "model__C": [0.01, 0.05, 0.1, 0.5, 1, 2, 5, 10, 50, 100]
}

# Wrap the full pipeline in GridSearchCV
grid_search = GridSearchCV(
    estimator=full_pipeline,
    param_grid=param_grid,
    cv=5,
    scoring="roc_auc",
    refit=True,
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train, y_train)

best_C       = grid_search.best_params_["model__C"]
best_score_cv = grid_search.best_score_

print(f"Best C found      : {best_C}")
print(f"Best CV ROC-AUC   : {best_score_cv:.4f}")

# %%
# Generate predictions from the tuned pipeline
tuned_preds  = grid_search.predict(X_test)
y_prob_tuned = grid_search.predict_proba(X_test)[:, 1]
roc_auc_tuned = roc_auc_score(y_test, y_prob_tuned)
pr_auc_tuned = average_precision_score(y_test, y_prob_tuned)

# Confusion Matrix (Tuned)
cm_tuned = confusion_matrix(y_test, tuned_preds)

fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(
    cm_tuned,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Attrition (0)", "Attrition (1)"],
    yticklabels=["No Attrition (0)", "Attrition (1)"],
    linewidths=0.5,
    ax=ax
)
ax.set_xlabel("Predicted Label", fontsize=11)
ax.set_ylabel("True Label", fontsize=11)
ax.set_title(
    f"Confusion Matrix – Tuned Logistic Regression (C = {best_C})",
    fontsize=12, fontweight="bold"
)
plt.tight_layout()
plt.show()

# Classification Report (Tuned)
print(f"Classification Report – Tuned Logistic Regression (C = {best_C})")
print("=" * 60)
print(classification_report(
    y_test, tuned_preds,
    target_names=["No Attrition (0)", "Attrition (1)"]
))

# ROC-AUC Score (Tuned)
print(f"ROC-AUC Score (Tuned) : {roc_auc_tuned:.4f}")

# ROC Curve: Baseline vs. Tuned
fpr_t, tpr_t, _ = roc_curve(y_test, y_prob_tuned)

fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(fpr_b, tpr_b, color="blue",   lw=2, linestyle="--",
        label=f"Baseline LR  (AUC = {roc_auc_baseline:.3f})")
ax.plot(fpr_t, tpr_t, color="orange", lw=2,
        label=f"Tuned LR (C={best_C})  (AUC = {roc_auc_tuned:.3f})")
ax.plot([0, 1], [0, 1], color="gray", linestyle="--", lw=1,
        label="Random Classifier")

ax.set_xlabel("False Positive Rate", fontsize=11)
ax.set_ylabel("True Positive Rate (Recall)", fontsize=11)
ax.set_title("ROC Curve – Baseline vs. Tuned Logistic Regression",
             fontsize=12, fontweight="bold")
ax.legend(loc="lower right", fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Classification Report – Tuned Logistic Regression (C = 2)
# ...
#                   precision    recall  f1-score   support
#
# No Attrition (0)       0.93      0.84      0.88       247
#    Attrition (1)       0.44      0.68      0.54        47
#
#         accuracy                           0.81       294
#        macro avg       0.69      0.76      0.71       294
#     weighted avg       0.85      0.81      0.83       294
#
# ROC-AUC Score (Tuned) : 0.8085

# %%
# F1-score for the Attrition class (class 1) for each model
f1_baseline = f1_score(y_test, test_preds,  pos_label=1)
f1_tuned    = f1_score(y_test, tuned_preds, pos_label=1)

# Build comparison table
comparison = pd.DataFrame({
    "Model"              : [f"Baseline LR (C=1.0)", f"Tuned LR (C={best_C})"],
    "ROC-AUC"            : [round(roc_auc_baseline, 4), round(roc_auc_tuned, 4)],
    "PR-AUC"             : [round(pr_auc_baseline, 4),  round(pr_auc_tuned, 4)],
    "F1 (Attrition = 1)" : [round(f1_baseline, 4),      round(f1_tuned, 4)],
})
comparison = comparison.set_index("Model")

print("Model Comparison – Baseline vs. Tuned Logistic Regression")
print("=" * 55)
display(comparison)

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# #### 4.1.3 Feature Importance — Logistic Regression
#
# The magnitude of standardised **coefficients** indicates each feature's contribution to the predicted log-odds of attrition. Positive coefficients increase attrition risk; negative coefficients reduce it. Because features are standardised, coefficients are directly comparable across variables.

# %%
# Extract feature names after one-hot encoding
ohe_features = (full_pipeline
                .named_steps["preprocessor"]
                .named_transformers_["cat"]
                .named_steps["encoder"]
                .get_feature_names_out(categorical_features)
                .tolist())

all_feature_names = numerical_features + ohe_features

# Extract coefficients from tuned model
coefficients = grid_search.best_estimator_.named_steps["model"].coef_[0]

# Build dataframe
feat_imp = pd.DataFrame({
    "Feature": all_feature_names,
    "Coefficient": coefficients
}).reindex(
    pd.Series(coefficients).abs().sort_values(ascending=False).index
).reset_index(drop=True)

# Plot top 15
top15 = feat_imp.head(15)

fig, ax = plt.subplots(figsize=(8, 6))
colors = ["#DD8452" if c < 0 else "#4C72B0" for c in top15["Coefficient"]]
ax.barh(top15["Feature"][::-1], top15["Coefficient"][::-1], color=colors[::-1])
ax.axvline(0, color="black", linewidth=0.8)
ax.set_title("Top 15 Feature Importances — Logistic Regression (Tuned)", fontweight="bold")
ax.set_xlabel("Coefficient (negative = lower attrition risk)")
plt.tight_layout()
plt.show()

display(feat_imp.head(15))

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# ### 4.2 Random Forest
#
# **Random Forest** is a **bagging ensemble** of decision trees. Each tree is trained on a bootstrap sample of the data with a random feature subset at each split, reducing variance and improving generalisation over a single decision tree. It naturally handles non-linear interactions and provides Gini-based feature importances.

# %% [markdown]
# #### 4.2.1 Baseline Model
#
# A baseline Random Forest is built using 100 trees with `class_weight="balanced"` and default depth settings. The pipeline preprocessor is cloned to ensure independent fitting from the Logistic Regression pipeline.

# %%
rf_pipeline = Pipeline(steps=[
    ("preprocessor", clone(preprocessor)),
    ("model", RandomForestClassifier(
        n_estimators=100,
        class_weight="balanced",
        random_state=42
    ))
])

rf_pipeline.fit(X_train, y_train)

rf_preds     = rf_pipeline.predict(X_test)
rf_proba     = rf_pipeline.predict_proba(X_test)[:, 1]
roc_auc_rf   = roc_auc_score(y_test, rf_proba)
pr_auc_rf    = average_precision_score(y_test, rf_proba)
f1_rf        = f1_score(y_test, rf_preds, pos_label=1)

print("Random Forest pipeline fitted.")
print(f"\nPredicted class distribution on test set : "
      f"{pd.Series(rf_preds).value_counts().sort_index().to_dict()}")
print(f"ROC-AUC Score : {roc_auc_rf:.4f}")
print(f"PR-AUC Score  : {pr_auc_rf:.4f}")

# %% [markdown]
# #### 4.2.2 Baseline Model Evaluation
#
# The baseline Random Forest is evaluated on the held-out test set using a confusion matrix, classification report, and ROC-AUC score to establish a performance benchmark before tuning.

# %%
# ── Confusion Matrix ──
cm_rf = confusion_matrix(y_test, rf_preds)

fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(
    cm_rf,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Attrition (0)", "Attrition (1)"],
    yticklabels=["No Attrition (0)", "Attrition (1)"],
    linewidths=0.5,
    ax=ax
)
ax.set_xlabel("Predicted Label", fontsize=11)
ax.set_ylabel("True Label", fontsize=11)
ax.set_title("Confusion Matrix – Baseline Random Forest",
             fontsize=12, fontweight="bold")
plt.tight_layout()
plt.show()

# ── Classification Report ──
print("Classification Report – Baseline Random Forest")
print("=" * 55)
print(classification_report(
    y_test, rf_preds,
    target_names=["No Attrition (0)", "Attrition (1)"]
))

# ── ROC-AUC & PR-AUC Scores ──
print(f"ROC-AUC Score : {roc_auc_rf:.4f}")
print(f"PR-AUC Score  : {pr_auc_rf:.4f}")

# ── ROC Curve: LR (Tuned) vs. Random Forest ──
fpr_rf, tpr_rf, _ = roc_curve(y_test, rf_proba)

fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(fpr_t, tpr_t, color="orange", lw=2,
        label=f"Tuned LR (C={best_C})  (AUC = {roc_auc_tuned:.3f})")
ax.plot(fpr_rf, tpr_rf, color="green", lw=2,
        label=f"Random Forest  (AUC = {roc_auc_rf:.3f})")
ax.plot([0, 1], [0, 1], color="gray", linestyle="--", lw=1,
        label="Random Classifier")

ax.set_xlabel("False Positive Rate", fontsize=11)
ax.set_ylabel("True Positive Rate (Recall)", fontsize=11)
ax.set_title("ROC Curve – Tuned LR vs. Random Forest",
             fontsize=12, fontweight="bold")
ax.legend(loc="lower right", fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Classification Report – Baseline Random Forest
# ...
#                   precision    recall  f1-score   support
#
# No Attrition (0)       0.85      0.98      0.91       247
#    Attrition (1)       0.43      0.06      0.11        47
#
#         accuracy                           0.84       294
#        macro avg       0.64      0.52      0.51       294
#     weighted avg       0.78      0.84      0.78       294
#
# ROC-AUC Score : 0.7788
# PR-AUC Score  : 0.3787

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# #### 4.2.3 Hyperparameter Tuning
#
# **`RandomizedSearchCV`** is used instead of grid search because the parameter space is large (five dimensions). 100 random configurations are evaluated with 5-fold cross-validation optimising ROC-AUC. Key parameters searched: number of trees, maximum depth, minimum samples per split/leaf, feature fraction, and class weighting strategy.

# %%
rf_param_distributions = {
    "model__n_estimators":      [500, 600, 700, 800, 1000],
    "model__max_depth":         [8, 9, 10, 11, 12, 15],
    "model__min_samples_split": [8, 10, 12, 15],
    "model__min_samples_leaf":  [4, 5, 6, 8],
    "model__max_features":      ["log2", 0.2, 0.25],
    "model__class_weight":      ["balanced", "balanced_subsample"],
    "model__max_samples":       [0.7, 0.8, 0.9],
}

rf_search = RandomizedSearchCV(
    estimator=rf_pipeline,
    param_distributions=rf_param_distributions,
    n_iter=100,
    cv=5,
    scoring="roc_auc",
    refit=True,

# %% [markdown]
# #### 4.2.4 Tuned Model Evaluation
#
# The best estimator from `RandomizedSearchCV` is evaluated on the test set to assess whether tuning improved performance over the baseline.

# %%
rf_tuned_preds = rf_search.best_estimator_.predict(X_test)
rf_tuned_proba = rf_search.best_estimator_.predict_proba(X_test)[:, 1]
roc_auc_rf_tuned = roc_auc_score(y_test, rf_tuned_proba)
pr_auc_rf_tuned  = average_precision_score(y_test, rf_tuned_proba)

print(f"Predicted class distribution on test set : "
      f"{pd.Series(rf_tuned_preds).value_counts().sort_index().to_dict()}")
print(f"ROC-AUC Score (Tuned RF) : {roc_auc_rf_tuned:.4f}")
print(f"PR-AUC Score  (Tuned RF) : {pr_auc_rf_tuned:.4f}\n")

# ── Confusion Matrix ──
cm_rf_tuned = confusion_matrix(y_test, rf_tuned_preds)

fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(
    cm_rf_tuned,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Attrition (0)", "Attrition (1)"],
    yticklabels=["No Attrition (0)", "Attrition (1)"],
    linewidths=0.5,
    ax=ax,
)
ax.set_xlabel("Predicted Label", fontsize=11)
ax.set_ylabel("True Label", fontsize=11)
ax.set_title("Confusion Matrix – Tuned Random Forest",
             fontsize=12, fontweight="bold")
plt.tight_layout()
plt.show()

# ── Classification Report ──
print("Classification Report – Tuned Random Forest")
print("=" * 55)
print(classification_report(
    y_test, rf_tuned_preds,
    target_names=["No Attrition (0)", "Attrition (1)"]
))

# ── ROC-AUC & PR-AUC Scores ──
print(f"ROC-AUC Score (Tuned RF) : {roc_auc_rf_tuned:.4f}")
print(f"PR-AUC Score  (Tuned RF) : {pr_auc_rf_tuned:.4f}\n")

# ── ROC Curve: Tuned LR vs. Baseline RF vs. Tuned RF ──
fpr_rf_tuned, tpr_rf_tuned, _ = roc_curve(y_test, rf_tuned_proba)

fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(fpr_t, tpr_t, color="orange", lw=2,
        label=f"Tuned LR (C={best_C})  (AUC = {roc_auc_tuned:.3f})")
ax.plot(fpr_rf, tpr_rf, color="green", lw=2, linestyle="--",
        label=f"Baseline RF  (AUC = {roc_auc_rf:.3f})")
ax.plot(fpr_rf_tuned, tpr_rf_tuned, color="darkgreen", lw=2,
        label=f"Tuned RF  (AUC = {roc_auc_rf_tuned:.3f})")
ax.plot([0, 1], [0, 1], color="gray", linestyle="--", lw=1,
        label="Random Classifier")

ax.set_xlabel("False Positive Rate", fontsize=11)
ax.set_ylabel("True Positive Rate (Recall)", fontsize=11)
ax.set_title("ROC Curve – Tuned LR vs. Baseline RF vs. Tuned RF",
             fontsize=12, fontweight="bold")
ax.legend(loc="lower right", fontsize=9)
plt.tight_layout()
plt.show()
# Out:
# Predicted class distribution on test set : {0: 258, 1: 36}
# ROC-AUC Score (Tuned RF) : 0.7800
# PR-AUC Score  (Tuned RF) : 0.3893
# Classification Report – Tuned Random Forest
# ...
#                   precision    recall  f1-score   support
#
# No Attrition (0)       0.87      0.91      0.89       247
#    Attrition (1)       0.39      0.30      0.34        47
#
#         accuracy                           0.81       294
#        macro avg       0.63      0.60      0.61       294
#     weighted avg       0.79      0.81      0.80       294
#
# ROC-AUC Score (Tuned RF) : 0.7800
# PR-AUC Score  (Tuned RF) : 0.3893

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# #### 4.2.5 LR vs RF Interim Comparison
#
# A summary table compares the Logistic Regression models with the Random Forest models across ROC-AUC, PR-AUC, and F1 (Attrition class). Full cross-model comparison including Gradient Boosting and Neural Network is in Section 5.6.

# %%
f1_rf_tuned = f1_score(y_test, rf_tuned_preds, pos_label=1)

final_comparison = pd.DataFrame({
    "Model"              : [f"Tuned LR (C={best_C})",
                            "Baseline RF",
                            "Tuned RF"],
    "ROC-AUC"            : [round(roc_auc_tuned, 4),
                            round(roc_auc_rf, 4),
                            round(roc_auc_rf_tuned, 4)],
    "PR-AUC"             : [round(pr_auc_tuned, 4),
                            round(pr_auc_rf, 4),
                            round(pr_auc_rf_tuned, 4)],
    "F1 (Attrition = 1)" : [round(f1_tuned, 4),
                            round(f1_rf, 4),
                            round(f1_rf_tuned, 4)],
})
final_comparison = final_comparison.set_index("Model")

print("Final Model Comparison")
print("=" * 60)
display(final_comparison)
# Out:
# Final Model Comparison
# ...
#                 ROC-AUC  PR-AUC  F1 (Attrition = 1)
# Model
# Tuned LR (C=2)   0.8085  0.5713              0.5378
# Baseline RF      0.7788  0.3787              0.1111
# Tuned RF         0.7800  0.3893              0.3373

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# #### 4.2.6 Feature Importance — Random Forest
#
# **Gini impurity-based importance** measures how much each feature reduces impurity (disorder) across all splits in all trees. Unlike Logistic Regression coefficients, these importances are non-negative and reflect non-linear contributions. Note that Gini importance can overestimate high-cardinality features; permutation importance (Section 4.3.5) provides a complementary, model-agnostic view.

# %%
# Extract feature names (same order as the ColumnTransformer output)
ohe_features_rf = (
    rf_search.best_estimator_
    .named_steps["preprocessor"]
    .named_transformers_["cat"]
    .named_steps["encoder"]
    .get_feature_names_out(categorical_features)
    .tolist()
)

all_feature_names_rf = numerical_features + ohe_features_rf

# Extract Gini importances from the tuned RF
rf_importances = rf_search.best_estimator_.named_steps["model"].feature_importances_

feat_imp_rf = pd.DataFrame({
    "Feature": all_feature_names_rf,
    "Importance": rf_importances
}).sort_values("Importance", ascending=False).reset_index(drop=True)

# Plot top 15
top15_rf = feat_imp_rf.head(15)

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(top15_rf["Feature"][::-1], top15_rf["Importance"][::-1], color="#4C72B0")
ax.set_title("Top 15 Feature Importances — Random Forest (Tuned)", fontweight="bold")
ax.set_xlabel("Mean Decrease in Impurity (Gini)")
plt.tight_layout()
plt.show()

display(feat_imp_rf.head(15))
# Out:
#                   Feature  Importance
# 0       log_MonthlyIncome    0.081926
# 1                     Age    0.067818
# 2   log_TotalWorkingYears    0.062529
# 3       SatisfactionIndex    0.060263
# 4                OverTime    0.056534
# 5      log_YearsAtCompany    0.052681
# 6        IncomeLevelRatio    0.051212
# 7    YearsWithCurrManager    0.048698
# 8             TenureRatio    0.047928
# 9    log_DistanceFromHome    0.040175
# 10       StockOptionLevel    0.039936
# 11     NumCompaniesWorked    0.036741
# 12     YearsInCurrentRole    0.035116
# 13               JobLevel    0.033559
# 14      PercentSalaryHike    0.031203

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# ### 4.3 Gradient Boosting
#
# **Gradient Boosting** builds an ensemble of shallow trees **sequentially**, where each tree corrects the residual errors of the previous one. Unlike Random Forest (which trains trees in parallel), boosting is a **boosting ensemble** that progressively reduces bias. The `learning_rate` parameter controls the contribution of each tree — lower values require more trees but generalise better.

# %%
gb_pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),   # reuse the exact same preprocessor from Section 3
    ("model", GradientBoostingClassifier(
        random_state=42,
        n_estimators=200,              # number of boosting rounds
        learning_rate=0.05,            # shrinkage — lower = more robust, needs more trees
        max_depth=4,                   # depth of each tree
        subsample=0.8,                 # fraction of samples per tree — reduces overfitting
        min_samples_leaf=20            # avoids splits on very few samples
    ))
])

# %% [markdown]
# #### 4.3.1 Baseline Model
#
# The baseline pipeline uses the initial hyperparameters and is fitted with **sample weights** computed from `compute_sample_weight("balanced")` — this is the recommended approach for `GradientBoostingClassifier`, which does not natively accept `class_weight`.

# %%
# Fit baseline with sample weights to handle class imbalance
sample_weights = compute_sample_weight("balanced", y_train)
gb_pipeline.fit(X_train, y_train, model__sample_weight=sample_weights)

y_pred_baseline_gb = gb_pipeline.predict(X_test)
y_proba_baseline_gb = gb_pipeline.predict_proba(X_test)[:, 1]

print("Initial Gradient Boosting — Test Set Performance")
print("=" * 50)
print(classification_report(y_test, y_pred_baseline_gb, target_names=["No Attrition", "Attrition"]))
print(f"ROC-AUC: {roc_auc_score(y_test, y_proba_baseline_gb):.4f}")

# %% [markdown]
# #### 4.3.2 Hyperparameter Tuning
#
# `GridSearchCV` with 5-fold cross-validation searches over the number of estimators, learning rate, maximum tree depth, and subsampling fraction, optimising ROC-AUC — consistent with the metric used for LR and RF tuning.

# %%
param_grid = {
    "model__n_estimators":  [100, 200, 300],
    "model__learning_rate": [0.01, 0.05, 0.1],
    "model__max_depth":     [3, 4, 5],
    "model__subsample":     [0.7, 0.8, 1.0],
}

gb_grid = GridSearchCV(
    gb_pipeline,
    param_grid,
    cv=5,
    scoring="roc_auc",    # same metric as LR section
    n_jobs=-1,
    verbose=1
)

# Pass sample weights to handle class imbalance (replaces class_weight="balanced")
sample_weights = compute_sample_weight("balanced", y_train)
gb_grid.fit(X_train, y_train, model__sample_weight=sample_weights)

# %%
best_gb = gb_grid.best_estimator_
y_pred  = best_gb.predict(X_test)
y_proba = best_gb.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred, target_names=["No Attrition", "Attrition"]))
print(f"ROC-AUC: {roc_auc_score(y_test, y_proba):.4f}")

# Confusion matrix
ConfusionMatrixDisplay.from_estimator(best_gb, X_test, y_test)

# ROC curve
RocCurveDisplay.from_estimator(best_gb, X_test, y_test)

# %% [markdown]
# The tuned Gradient Boosting model is evaluated on the held-out test set. Results below feed into the final comparison in Section 5.6.

# %% [markdown]
# #### 4.3.3 Threshold Tuning
#
# By default, `predict()` uses a threshold of 0.5 to convert probabilities to class labels. For imbalanced classification problems where **false negatives are costly** (missed leavers), a lower threshold increases recall at the expense of precision. The optimal threshold is selected using 5-fold cross-validation on the training set only — the test set is not touched until the final evaluation.

# %%
# Find best threshold using cross-validation on training set only
# This avoids using the test set for threshold selection
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
y_train_proba_cv = cross_val_predict(
    gb_grid.best_estimator_,
    X_train, y_train,
    cv=cv,
    method="predict_proba"
)[:, 1]

# Find best threshold on training CV probabilities
thresholds = np.arange(0.30, 0.51, 0.05)
results_threshold = []

for t in thresholds:
    preds_t = (y_train_proba_cv >= t).astype(int)
    f1_t = f1_score(y_train, preds_t, pos_label=1)
    results_threshold.append({"Threshold": round(t, 2), "F1 (Attrition) - CV": round(f1_t, 4)})

threshold_df = pd.DataFrame(results_threshold)
print("Threshold Tuning Results (Cross-Validation on Training Set):")
print(threshold_df.to_string(index=False))

# Select best threshold from CV
best_row = threshold_df.loc[threshold_df["F1 (Attrition) - CV"].idxmax()]
best_threshold = best_row["Threshold"]
print(f"\nBest threshold (from CV): {best_threshold} — F1: {best_row['F1 (Attrition) - CV']}")

# Apply chosen threshold ONCE to the untouched test set
y_pred_best_threshold = (y_proba >= best_threshold).astype(int)
print("\nClassification Report at Best Threshold (applied to test set):")
print(classification_report(y_test, y_pred_best_threshold, target_names=["No Attrition", "Attrition"]))

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %%
comparison_gb = pd.DataFrame({
    "Model": ["Initial GB", "Tuned GB"],
    "ROC-AUC": [round(roc_auc_score(y_test, y_proba_baseline_gb), 4),
                round(roc_auc_score(y_test, y_proba), 4)],
    "F1 (Attrition = 1)": [round(f1_score(y_test, y_pred_baseline_gb), 4),
                            round(f1_score(y_test, y_pred), 4)],
}).set_index("Model")

print("Model Comparison — Initial vs Tuned Gradient Boosting")
print("=" * 50)
display(comparison_gb)

# %%
# Get feature importances from the fitted model
importances = gb_grid.best_estimator_.named_steps["model"].feature_importances_

# You need feature names — get them the same way as the LR section did
ohe_features = (preprocessor
                .named_transformers_["cat"]
                .named_steps["encoder"]
                .get_feature_names_out(categorical_features).tolist())

all_features = numerical_features + ohe_features

feat_imp_df = pd.DataFrame({
    "Feature": all_features,
    "Importance": importances
}).sort_values("Importance", ascending=False).head(15)

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(feat_imp_df["Feature"][::-1], feat_imp_df["Importance"][::-1], color="#4C72B0")
ax.set_title("Top 15 Feature Importances — Gradient Boosting (Tuned)", fontweight="bold")
ax.set_xlabel("Feature Importance (Gain)")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.3.4 Feature Importance — Gradient Boosting
#
# **Gain-based feature importance** (sum of impurity reduction across all splits for each feature) indicates which features were most useful for building the boosted ensemble. This is the model's own internal view of importance.

# %% [markdown]
# #### 4.3.5 Permutation Feature Importance
#
# **Permutation importance** is a model-agnostic technique: each feature is randomly shuffled in the test set and the resulting drop in ROC-AUC is measured. A large drop indicates the feature is important; no drop suggests the model does not rely on it. This corrects for the tendency of Gini importance to overstate the importance of high-cardinality or correlated features.

# %%
# When passing X_test (raw) to the full pipeline, importances are for original features
# so we use X_test.columns as feature names, not the post-OHE names
perm_result = permutation_importance(
    gb_grid.best_estimator_,
    X_test, y_test,
    n_repeats=10,
    random_state=42,
    scoring="roc_auc"
)

print(f"Features: {len(X_test.columns)}, Importances: {len(perm_result.importances_mean)}")

perm_df = pd.DataFrame({
    "Feature": X_test.columns.tolist(),
    "Importance Mean": perm_result.importances_mean,
    "Importance Std":  perm_result.importances_std
}).sort_values("Importance Mean", ascending=False).head(15)

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(perm_df["Feature"][::-1], perm_df["Importance Mean"][::-1],
        xerr=perm_df["Importance Std"][::-1], color="#4C72B0", edgecolor="white")
ax.set_title("Permutation Feature Importance — Gradient Boosting", fontweight="bold")
ax.set_xlabel("Mean decrease in ROC-AUC when feature is shuffled")
plt.tight_layout()
plt.show()

print("Top 5 most important features (Permutation):")
print(perm_df[["Feature", "Importance Mean"]].head(5).to_string(index=False))

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# #### 4.3.6 LR vs GB Interim Comparison
#
# A combined summary table comparing Logistic Regression and Gradient Boosting across ROC-AUC, F1, and PR-AUC. Full four-model comparison is in Section 5.6.

# %%
# Final comparison — Logistic Regression vs Gradient Boosting
final_comparison = pd.DataFrame({
    "Model": ["Tuned Logistic Regression", "Tuned Gradient Boosting"],
    "ROC-AUC": [round(roc_auc_tuned, 4),
                round(roc_auc_score(y_test, y_proba), 4)],
    "F1 (Attrition = 1)": [round(f1_tuned, 4),
                            round(f1_score(y_test, y_pred), 4)],
    "PR-AUC": [round(pr_auc_tuned, 4),
               round(average_precision_score(y_test, y_proba), 4)],
}).set_index("Model")

print("Final Model Comparison — Logistic Regression vs Gradient Boosting")
print("=" * 60)
display(final_comparison)

# %% [markdown]
# ### 4.4 Neural Network (TensorFlow/Keras)
#
# A **fully connected feed-forward neural network** built with TensorFlow/Keras is trained as the most complex model in the comparison. Neural networks can learn highly non-linear relationships and feature interactions automatically, but require more data and careful regularisation to avoid overfitting. This section covers architecture design, class imbalance handling, and training with early stopping.

# %% [markdown]
# All TensorFlow/Keras imports are consolidated in the **Imports** cell at the top of this notebook. TensorFlow version is printed by the next code cell.

# %%
# All TensorFlow / Keras and supporting imports are consolidated at the top of this notebook.
print(f"TensorFlow version: {tf.__version__}")

# %% [markdown]
# #### 4.4.0 Data Preparation for Neural Network
#
# Keras requires plain NumPy arrays as input rather than DataFrames. The **same `ColumnTransformer` preprocessor** from Section 3.5 is used here — fitted on training data only — to produce `float32` arrays compatible with TensorFlow.

# %%
# Fit preprocessor on training data only
X_train_pre = preprocessor.fit_transform(X_train)
X_test_pre = preprocessor.transform(X_test)

# Ensure numpy float32 for TensorFlow
X_train_pre = np.asarray(X_train_pre).astype("float32")
X_test_pre = np.asarray(X_test_pre).astype("float32")

y_train_nn = np.asarray(y_train).astype("float32")
y_test_nn = np.asarray(y_test).astype("float32")

print("Preprocessed training shape:", X_train_pre.shape)
print("Preprocessed test shape:", X_test_pre.shape)
print("Data type:", X_train_pre.dtype)

# %% [markdown]
# #### 4.4.1 Architecture & Design Choices
#
# We build a two-hidden-layer **fully connected network** with **L2 regularisation** and **Dropout** to combat overfitting on this relatively small dataset (~1,200 training examples). The output layer uses a **sigmoid** activation for binary classification. **Adam** optimiser is used with a fixed learning rate; **AUC** is monitored as the primary metric to align with the business objective.

# %%
def build_tf_model(input_dim, learning_rate=0.001, l2_strength=0.001, dropout_rate=0.30):
    model = keras.Sequential([
        layers.Input(shape=(input_dim,)),
        
        layers.Dense(
            64,
            activation="relu",
            kernel_regularizer=regularizers.l2(l2_strength)
        ),
        layers.Dropout(dropout_rate),
        
        layers.Dense(
            32,
            activation="relu",
            kernel_regularizer=regularizers.l2(l2_strength)
        ),
        layers.Dropout(dropout_rate),
        
        layers.Dense(1, activation="sigmoid")
    ])
    
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss="binary_crossentropy",
        metrics=[
            keras.metrics.AUC(name="auc"),
            keras.metrics.Precision(name="precision"),
            keras.metrics.Recall(name="recall")
        ]
    )
    
    return model

tf_model = build_tf_model(input_dim=X_train_pre.shape[1])
tf.random.set_seed(42)
tf_model.summary()

# %% [markdown]
# The model summary confirms the input dimension (42 features after OHE) and the total number of trainable parameters. The sigmoid output maps the network score to an attrition probability in [0, 1].

# %% [markdown]
# #### 4.4.2 Class Imbalance Handling
#
# Keras does not support `class_weight` in the same way as sklearn. Instead, **`compute_class_weight("balanced")`** is used to calculate per-class weights that are passed to `model.fit()` via the `class_weight` argument, upweighting the minority attrition class during training.

# %%
classes = np.unique(y_train_nn)
class_weights_array = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train_nn
)

class_weight_dict = {
    int(cls): float(weight)
    for cls, weight in zip(classes, class_weights_array)
}

print("Class weights:", class_weight_dict)

# %% [markdown]
# The weight for class 1 (Attrition) is roughly five times that of class 0, reflecting the ~84/16 imbalance ratio. This ensures the loss penalises missed attrition cases more heavily throughout training.

# %% [markdown]
# #### 4.4.3 Training & Early Stopping
#
# The model trains for up to **100 epochs** with **20% of the training data held out as a validation set**. **Early stopping** (patience = 10) monitors validation AUC and halts training when performance stops improving, restoring the best weights automatically. This prevents overfitting without manual epoch selection.

# %%
early_stopping = callbacks.EarlyStopping(
    monitor="val_auc",
    mode="max",
    patience=10,
    restore_best_weights=True,
    verbose=1
)

history = tf_model.fit(
    X_train_pre,
    y_train_nn,
    validation_split=0.10,
    epochs=100,
    batch_size=32,
    class_weight=class_weight_dict,
    callbacks=[early_stopping],
    verbose=1
)

history_df = pd.DataFrame(history.history)

# %% [markdown]
# **Training History: AUC & Loss Curves**
#
# AUC and Loss are plotted side by side for training and validation sets across epochs. Divergence between training and validation curves indicates overfitting; convergence without improvement suggests underfitting or early stopping was triggered at the right point.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# AUC
axes[0].plot(history_df.index + 1, history_df["auc"],     label="Train AUC",      color="steelblue")
axes[0].plot(history_df.index + 1, history_df["val_auc"], label="Validation AUC", color="orange", linestyle="--")
axes[0].set_title("Train vs Validation AUC")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("AUC")
axes[0].legend()
axes[0].grid(True)

# Loss
axes[1].plot(history_df.index + 1, history_df["loss"],     label="Train Loss",      color="steelblue")
axes[1].plot(history_df.index + 1, history_df["val_loss"], label="Validation Loss", color="orange", linestyle="--")
axes[1].set_title("Train vs Validation Loss")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("TensorFlow Neural Network — Training History", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# #### 4.4.4 Threshold Optimisation
#
# The same cross-validation threshold tuning approach used for Gradient Boosting (Section 4.3.3) is applied here: thresholds between 0.10 and 0.90 are evaluated on predicted probabilities, and the threshold maximising F1 for the Attrition class is selected. The chosen threshold is then applied once to the held-out test set.

# %%
tf_prob = tf_model.predict(X_test_pre).ravel()
thresholds = np.arange(0.10, 0.91, 0.01)

threshold_results = []
for threshold in thresholds:
    preds_thr = (tf_prob >= threshold).astype(int)
    f1_thr = f1_score(y_test_nn, preds_thr, pos_label=1)
    threshold_results.append({
        "threshold": threshold,
        "f1_attrition_1": f1_thr
    })

threshold_df = pd.DataFrame(threshold_results)
best_row = threshold_df.loc[threshold_df["f1_attrition_1"].idxmax()]
best_threshold = float(best_row["threshold"])
best_f1_threshold = float(best_row["f1_attrition_1"])

print(f"Best threshold : {best_threshold:.2f}")
print(f"Best F1 (Attrition) at best threshold: {best_f1_threshold:.4f}")

# %% [markdown]
# **Evaluation at Best Threshold**
#
# The model is evaluated on the test set using the threshold selected in Section 4.4.4. Confusion matrix and classification report are shown below.

# %%
tf_preds_best = (tf_prob >= best_threshold).astype(int)

cm_tf_best = confusion_matrix(y_test_nn, tf_preds_best)

fig, ax = plt.subplots(figsize=(5, 4))
sns.heatmap(
    cm_tf_best,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["No Attrition (0)", "Attrition (1)"],
    yticklabels=["No Attrition (0)", "Attrition (1)"],
    linewidths=0.5,
    ax=ax
)
ax.set_xlabel("Predicted Label", fontsize=11)
ax.set_ylabel("True Label", fontsize=11)
ax.set_title(f"Confusion Matrix – TensorFlow NN (Threshold = {best_threshold:.2f})",
             fontsize=12, fontweight="bold")
plt.tight_layout()
plt.show()

print("Classification Report – TensorFlow Neural Network (Best Threshold)")
print("=" * 70)
print(classification_report(
    y_test_nn,
    tf_preds_best,
    target_names=["No Attrition (0)", "Attrition (1)"]
))

f1_tf_best = f1_score(y_test_nn, tf_preds_best, pos_label=1)
roc_tf = roc_auc_score(y_test_nn, tf_prob)
print(f"ROC-AUC                          : {roc_tf:.4f}")
print(f"F1 Score (Attrition, best thr.)  : {f1_tf_best:.4f}")
print(f"Chosen threshold                 : {best_threshold:.2f}")

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*

# %% [markdown]
# 🔲 *Interpretation to be added after notebook run.*
#
# > **Future Improvements** for the Neural Network are captured in Section 6.3.

# %% [markdown]
# ---
#
# ## 5. Model Evaluation & Comparison
#
# This section consolidates all evaluation results across the four model families. The goal is to select the model that best balances predictive performance, interpretability, and suitability for the business use case — not simply the model with the highest accuracy.
#
# ---
#
# ### 5.1 Evaluation Methodology
#
# Each model is assessed on the **held-out test set** (20% of data, never seen during training or tuning) using the following metrics:
#
# | Metric | Why it matters for attrition prediction |
# |---|---|
# | **ROC-AUC** | Measures ranking ability across all thresholds; robust to class imbalance |
# | **PR-AUC** | Precision-Recall AUC; more informative than ROC-AUC when the positive class (attrition) is rare |
# | **F1 (Attrition)** | Harmonic mean of precision and recall for the minority class; captures the trade-off between catching leavers and minimising false alarms |
# | **Recall (Attrition)** | Proportion of actual leavers correctly identified — high recall reduces costly missed leavers |
# | **Precision (Attrition)** | Proportion of predicted leavers who actually leave — prevents wasting HR intervention budget |
#
# A **threshold of 0.5** is used as the default; threshold tuning was applied to Gradient Boosting and Neural Network to optimise F1 for the minority class.
#
# ---
#
# ### 5.2 Logistic Regression — Full Evaluation
#
# Confusion matrix, classification report, ROC curve, and feature importance coefficients are in **Section 4.1** (inline with training, for execution order reasons).
#
# 🔲 *Summary interpretation to be added after notebook run.*
#
# ---
#
# ### 5.3 Random Forest — Full Evaluation
#
# Confusion matrix, classification report, ROC curve, and Gini feature importances are in **Section 4.2** (inline with training).
#
# 🔲 *Summary interpretation to be added after notebook run.*
#
# ---
#
# ### 5.4 Gradient Boosting — Full Evaluation
#
# Evaluation on test set, threshold tuning results, gain-based and permutation feature importances are in **Section 4.3** (inline with training).
#
# 🔲 *Summary interpretation to be added after notebook run.*
#
# ---
#
# ### 5.5 Neural Network — Full Evaluation
#
# Training history (AUC & Loss curves), threshold optimisation, and evaluation at best threshold are in **Section 4.4** (inline with training).
#
# 🔲 *Summary interpretation to be added after notebook run.*
#
# ---
#
# ### 5.6 Final Model Comparison
#
# The cell below compares all models that have been evaluated. A full four-model summary table should be compiled here after all models have been run.
#
# 🔲 *Full comparison table and recommended model to be completed after notebook run.*

# %% [markdown]
# ---
#
# ## 6. Business Interpretation & Recommendations
#
# The models have now been trained and evaluated. This section translates the technical findings into actionable business language — identifying the key drivers of attrition, proposing targeted HR interventions, and acknowledging the limitations of the analysis.
#
# ---
#
# ### 6.1 Key Drivers of Employee Attrition
#
# 🔲 *Interpretation to be added after notebook run.*
#
# ---
#
# ### 6.2 Actionable Business Recommendations
#
# 🔲 *Interpretation to be added after notebook run.*
#
# ---
#
# ### 6.3 Limitations & Future Improvements
#
# **Current limitations:**
# - The dataset is synthetic (IBM HR simulation) and may not reflect real workforce dynamics.
# - The Neural Network is constrained by the small dataset size (~1,200 training examples), which limits its advantage over tree-based models.
# - Feature importance methods (Gini, coefficients) do not establish causality — correlation with attrition does not mean the feature *causes* attrition.
#
# **Potential future improvements:**
# - Incorporate additional data sources (e.g. engagement survey scores, manager ratings, absenteeism records).
# - Experiment with **XGBoost** or **LightGBM** as more efficient boosting alternatives.
# - Apply **SHAP values** for a unified, additive feature importance framework across all model types.
# - Develop a **time-aware model** using longitudinal HR data to predict attrition risk at specific career milestones.
# - Build an **HR dashboard** that surfaces the top at-risk employees with explanations for each prediction.

# %% [markdown]
# ## References
#
# - IBM HR Analytics Employee Attrition & Performance dataset — [Kaggle](https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset)
# - Pedregosa et al. (2011). Scikit-learn: Machine Learning in Python. *JMLR*, 12, 2825–2830.
# - Abadi et al. (2016). TensorFlow: A System for Large-Scale Machine Learning. *OSDI*.
# - Friedman, J.H. (2001). Greedy Function Approximation: A Gradient Boosting Machine. *Annals of Statistics*, 29(5), 1189–1232.
# - Breiman, L. (2001). Random Forests. *Machine Learning*, 45, 5–32.
